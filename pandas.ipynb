# %% [markdown]
# #Python_pandas

# %%
import pandas as pd

# %% [markdown]
# ##task_1

# %%
movi = pd.read_csv('movies.csv',)
movi[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f0d401d16b95> in <module>
# ----> 1 movi = pd.read_csv('movies.csv',)
#       2 movi[:10]
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
rating = pd.read_csv('ratings.csv')
rating[:5]
# Out:
#    userId  movieId  rating   timestamp
# 0       1      307     3.5  1256677221
# 1       1      481     3.5  1256677456
# 2       1     1091     1.5  1256677471
# 3       1     1257     4.5  1256677460
# 4       1     1449     4.5  1256677264

# %%
merge_movi = movi.merge(rating,
                        left_on= 'movieId',
                        right_on = 'movieId'
                        )
merge_movi[:5]
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       4     4.0  1113765937
# 1      10     5.0   948885850
# 2      14     4.5  1442169375
# 3      15     4.0  1370810063
# 4      22     4.0  1237622631

# %%
from os import access
merge_movi.groupby('title').agg({'rating':['max','count']}).sort_values(['count'])[:1]
# Out:
#                                  rating
#                                     max count
# title
# "Great Performances" Cats (1998)    5.0    39

# %% [markdown]
# ##task_2

# %% [markdown]
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 год. Не учитывайте в расчётах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
power2=power[(power['year']>=2005)&(power['year']<=2010)&(power['quantity']>0)]

res=power2[power2.category.isin([4,12,21])]

res[res.country.str.contains('|'.join(['Latvia','Lithuania','Estonia']))]['quantity'].sum()
# Out:
# 240580.0

# %%
eu_sd,material,update,metal,oil,procent,stocks,update_2 = pd.read_html('https://fortrader.org/quotes')

# %%
eu_sd.head()
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  78.94       0.38          0.48        NaN
# 1       USDRUB Курс рубля к доллару  74.05       0.49          0.67        NaN

# %%
material[:5]
# Out:
#                               Название    Цена  Изменение  Изменение(%)  \
# 0       Нефть Brent Курс нефти сегодня   83.38      -0.35         -0.42
# 1          Нефть WTI Цены на нефть WTI   76.66      -0.45         -0.58
# 2  Природный газ Цена на природный газ    2.18      -0.06         -2.68
# 3                                 Кофе  188.35      -1.50         -0.79
# 4                             Кукуруза  681.20       3.60          0.53
#
#    Обновлено
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
stocks[:5]
# Out:
#                     Название       Цена  Изменение  Изменение(%)  Обновлено
# 0  EUR/USD Евро / Доллар США    1.06575   -0.00245      -0.22936        NaN
# 1  GBP/USD Фунт / Доллар США    1.21085    0.00705       0.58565        NaN
# 2     USD/CHF Доллар / Франк    0.92481    0.00157       0.17005        NaN
# 3  USD/JPY Доллар США / Иена  134.86600    0.52700       0.39200        NaN
# 4      USD/CNH Доллар / Юань    6.88555    0.02755       0.40172        NaN
